# %%
2+4
# Out:
# 6

# %%
a=3
print(a)
# Out:
# 3

# %%
import pandas as pd
train = pd.read_csv("Downloads/datafiles19cdaf8/train.csv)
# Out:
#   File "<ipython-input-3-ffe7802d5f46>", line 2
#     train = pd.read_csv("Downloads/datafiles19cdaf8/train.csv)
#                                                               ^
# SyntaxError: EOL while scanning string literal

# %%
import pandas as pd
train = pd.read_csv("Downloads/datafiles19cdaf8/train.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-4c41ca2cfa9e> in <module>
#       1 import pandas as pd
# ----> 2 train = pd.read_csv("Downloads/datafiles19cdaf8/train.csv")
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
import pandas as pd
train = pd.read_csv("~/Adult/train.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-358a0ec9a1bd> in <module>
#       1 import pandas as pd
# ----> 2 train = pd.read_csv("~/Adult/train.csv")
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
import pandas as pd
train = pd.read_csv("/Users/apple/Downloads/datafiles19cdaf8/train.csv")

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         30725 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education.num     32561 non-null int64
# marital.status    32561 non-null object
# occupation        30718 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital.gain      32561 non-null int64
# capital.loss      32561 non-null int64
# hours.per.week    32561 non-null int64
# native.country    31978 non-null object
# target            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
print('train dataset has',train.shape())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-c1c1605fdc59> in <module>
# ----> 1 print('train dataset has',train.shape())
#
# TypeError: 'tuple' object is not callable

# %%
test = pd.read_csv("/Users/apple/Downloads/datafiles19cdaf8/test.csv")

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16281 entries, 0 to 16280
# Data columns (total 15 columns):
# age               16281 non-null int64
# workclass         15318 non-null object
# fnlwgt            16281 non-null int64
# education         16281 non-null object
# education.num     16281 non-null int64
# marital.status    16281 non-null object
# occupation        15315 non-null object
# relationship      16281 non-null object
# race              16281 non-null object
# sex               16281 non-null object
# capital.gain      16281 non-null int64
# capital.loss      16281 non-null int64
# hours.per.week    16281 non-null int64
# native.country    16007 non-null object
# target            16281 non-null object
# dtypes: int64(6), object(9)
# memory usage: 1.9+ MB

# %%
print("train dataset has",train.shape())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-a72813a80a20> in <module>
# ----> 1 print("train dataset has",train.shape())
#
# TypeError: 'tuple' object is not callable

# %%
print ("train dataset has",train.shape)
# Out:
# train dataset has (32561, 15)

# %%
train.head()
# Out:
#    age          workclass  fnlwgt   education  education.num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital.status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital.gain  capital.loss  hours.per.week  native.country  target
# 0          2174             0              40   United-States   <=50K
# ...

# %%
nans = train.shape[0]-train.dropna().shape[0]

# %%
print("%d rows have missing value",%nans)
# Out:
#   File "<ipython-input-15-9460862dac5d>", line 1
#     print("%d rows have missing value",%nans)
#                                        ^
# SyntaxError: invalid syntax

# %%
print("%d rows have missing values"%nans)
# Out:
# 2399 rows have missing values

# %%
tain.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-4889d5c61f4c> in <module>
# ----> 1 tain.isnull().sum()
#
# NameError: name 'tain' is not defined

# %%
train.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# target               0
# dtype: int64

# %%
cat = train.select_dtypes(include=['0'])
cat.apply(pd.Series.nunique)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-d5d923b2d70c> in <module>
# ----> 1 cat = train.select_dtypes(include=['0'])
#       2 cat.apply(pd.Series.nunique)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in select_dtypes(self, include, exclude)
#    3304         # convert the myriad valid dtypes object to a single representation
#    3305         include, exclude = map(
# -> 3306             lambda x: frozenset(map(infer_dtype_from_object, x)), selection)
#    3307         for dtypes in (include, exclude):
#    3308             invalidate_string_dtypes(dtypes)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in <lambda>(x)
#    3304         # convert the myriad valid dtypes object to a single representation
#    3305         include, exclude = map(
# ...

# %%
cat = train.select_dtypes(include=['o'])
cat.apply(pd.Series.nunique)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-4e52ec336445> in <module>
# ----> 1 cat = train.select_dtypes(include=['o'])
#       2 cat.apply(pd.Series.nunique)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in select_dtypes(self, include, exclude)
#    3304         # convert the myriad valid dtypes object to a single representation
#    3305         include, exclude = map(
# -> 3306             lambda x: frozenset(map(infer_dtype_from_object, x)), selection)
#    3307         for dtypes in (include, exclude):
#    3308             invalidate_string_dtypes(dtypes)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in <lambda>(x)
#    3304         # convert the myriad valid dtypes object to a single representation
#    3305         include, exclude = map(
# ...

# %%
import pandas as pd
weather = pd.read_csv("/Users/apple/Downloads/py-master/pandas/1_intro/nyc_weather.csv")

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
# EST                     31 non-null object
# Temperature             31 non-null int64
# DewPoint                31 non-null int64
# Humidity                31 non-null int64
# Sea Level PressureIn    31 non-null float64
# VisibilityMiles         31 non-null int64
# WindSpeedMPH            28 non-null float64
# PrecipitationIn         31 non-null object
# CloudCover              31 non-null int64
# Events                  9 non-null object
# WindDirDegrees          31 non-null int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 2.7+ KB

# %%
weather
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
weather.shape
# Out:
# (31, 11)

# %%
weather.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
weather.tail()
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 26               10           7.0               T           3   Rain
# 27               10           5.0               0           1    NaN
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
weather.tail(1)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 30  1/31/2016           46        28        52                  29.9
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 30             241

# %%
weather[2:4]
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
#
#    WindDirDegrees
# 2             277
# 3             345

# %%
weather.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
weather['Temperature']
# Out:
# 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64

# %%
type(weather['Temperature'])
# Out:
# pandas.core.series.Series

# %%
weather[['Temperature','DewPoint']]
# Out:
#     Temperature  DewPoint
# 0            38        23
# 1            36        18
# 2            40        21
# 3            25         9
# 4            20        -3
# 5            33         4
# 6            39        11
# 7            39        29
# 8            44        38
# 9            50        46
# 10           33         8
# 11           35        15
# 12           26         4
# 13           30        12
# 14           43        31
# 15           47        37
# 16           36        23
# 17           25         6
# 18           22         3
# 19           32        15
# 20           31        11
# 21           26         6
# 22           26        21
# 23           28        11
# 24           34        18
# 25           43        29
# 26           41        22
# 27           37        20
# 28           36        21
# 29           34        16
# 30           46        28

# %%
weather['Temperature'].max()
# Out:
# 50

# %%
weather[['Temperature','DewPoint']].max()
# Out:
# Temperature    50
# DewPoint       46
# dtype: int64

# %%
weather[['Temperature','DewPoint']].std
# Out:
# <bound method DataFrame.std of     Temperature  DewPoint
# 0            38        23
# 1            36        18
# 2            40        21
# 3            25         9
# 4            20        -3
# 5            33         4
# 6            39        11
# 7            39        29
# 8            44        38
# 9            50        46
# 10           33         8
# 11           35        15
# 12           26         4
# 13           30        12
# 14           43        31
# 15           47        37
# 16           36        23
# 17           25         6
# 18           22         3
# 19           32        15
# 20           31        11
# 21           26         6
# 22           26        21
# 23           28        11
# 24           34        18
# 25           43        29
# 26           41        22
# 27           37        20
# 28           36        21
# 29           34        16
# 30           46        28>

# %%
weather[['Temperature','DewPoint']].std()
# Out:
# Temperature     7.639315
# DewPoint       11.378626
# dtype: float64

# %%
weather.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
weather[weather.temperature > =35]
# Out:
#   File "<ipython-input-18-7f0d0652070c>", line 1
#     weather[weather.temperature > =35]
#                                   ^
# SyntaxError: invalid syntax

# %%
weather[weather.temperature >= 35]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-d58c387a396d> in <module>
# ----> 1 weather[weather.temperature >= 35]
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'temperature'

# %%
weather[weather.temperature>=35]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-6a4f59e8ff0b> in <module>
# ----> 1 weather[weather.temperature>=35]
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'temperature'

# %%
weather[weather.Temperature > =35]
# Out:
#   File "<ipython-input-21-65e31cd73a1b>", line 1
#     weather[weather.Temperature > =35]
#                                   ^
# SyntaxError: invalid syntax

# %%
weather[weather.Temperature>=35]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 11  1/12/2016           35        15        53                 29.85
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# ...

# %%
weather[weather.Temperature==weather.Temperature.max()]
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                4           NaN             1.8           7   Rain
#
#    WindDirDegrees
# 9             109

# %%
weather['Temperature'][weather.Temperature==weather.Temperature.max()]
# Out:
# 9    50
# Name: Temperature, dtype: int64

# %%
weather['Temperature','DewPoint'][weather.Temperature==weather.Temperature.max()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Temperature', 'DewPoint')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-00a655484029> in <module>
# ...

# %%
weather[['Temperature','DewPoint']][weather.Temperature==weather.Temperature.max()]
# Out:
#    Temperature  DewPoint
# 9           50        46

# %%
weather.set_index('EST')
# Out:
#            Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 1/1/2016            38        23        52                 30.03
# 1/2/2016            36        18        46                 30.02
# 1/3/2016            40        21        47                 29.86
# 1/4/2016            25         9        44                 30.05
# 1/5/2016            20        -3        41                 30.57
# 1/6/2016            33         4        35                 30.50
# 1/7/2016            39        11        33                 30.28
# 1/8/2016            39        29        64                 30.20
# 1/9/2016            44        38        77                 30.16
# 1/10/2016           50        46        71                 29.59
# 1/11/2016           33         8        37                 29.92
# 1/12/2016           35        15        53                 29.85
# 1/13/2016           26         4        42                 29.94
# ...

# %%
weather.set_index('EST',implace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-6a63d25edfe4> in <module>
# ----> 1 weather.set_index('EST',implace=True)
#
# TypeError: set_index() got an unexpected keyword argument 'implace'

# %%
weather.set_index('EST',inplace=True)

# %%
weather
# Out:
#            Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 1/1/2016            38        23        52                 30.03
# 1/2/2016            36        18        46                 30.02
# 1/3/2016            40        21        47                 29.86
# 1/4/2016            25         9        44                 30.05
# 1/5/2016            20        -3        41                 30.57
# 1/6/2016            33         4        35                 30.50
# 1/7/2016            39        11        33                 30.28
# 1/8/2016            39        29        64                 30.20
# 1/9/2016            44        38        77                 30.16
# 1/10/2016           50        46        71                 29.59
# 1/11/2016           33         8        37                 29.92
# 1/12/2016           35        15        53                 29.85
# 1/13/2016           26         4        42                 29.94
# ...

# %%
weather.loc['1/29/2016']
# Out:
# Temperature                36
# DewPoint                   21
# Humidity                   50
# Sea Level PressureIn    29.58
# VisibilityMiles            10
# WindSpeedMPH                8
# PrecipitationIn             0
# CloudCover                  4
# Events                    NaN
# WindDirDegrees            298
# Name: 1/29/2016, dtype: object

# %%
pd=read_csv("/Users/apple/Downloads/py-master/pandas/4_read_write_to_excel/stock_data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-4b591b940760> in <module>
# ----> 1 pd=read_csv("/Users/apple/Downloads/py-master/pandas/4_read_write_to_excel/stock_data.csv")
#
# NameError: name 'read_csv' is not defined

# %%
df=pd.read_csv("/Users/apple/Downloads/py-master/pandas/4_read_write_to_excel/stock_data.csv")

# %%
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df=pd.read_csv("/Users/apple/Downloads/py-master/pandas/4_read_write_to_excel/stock_data.csv",header=None)

# %%
df
# Out:
#          0              1        2      3              4
# 0  tickers            eps  revenue  price         people
# 1    GOOGL          27.82       87    845     larry page
# 2      WMT           4.61      484     65           n.a.
# 3     MSFT             -1       85     64     bill gates
# 4     RIL   not available       50   1023  mukesh ambani
# 5     TATA            5.6       -1   n.a.     ratan tata

# %%
df.to_csv('new.csv')

# %%
df.to_csv('new.csv',index=False)

# %%
dd=pd.read_csv("/Users/apple/Downloads/py-master/pandas/4_read_write_to_excel/stock_data.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-39-bf9c10c602b4> in <module>
# ----> 1 dd=pd.read_csv("/Users/apple/Downloads/py-master/pandas/4_read_write_to_excel/stock_data.xlsx")
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
dd=pd.read_excel("/Users/apple/Downloads/py-master/pandas/4_read_write_to_excel/stock_data.xlsx")

# %%
dd
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
def convert_people_cell(cell):
    if cell=="n.a.":
        return 'Bindu'
    return cell
dd=pd.read_excel("/Users/apple/Downloads/py-master/pandas/4_read_write_to_excel/stock_data.xlsx","Sheet1",converters = {
    'people':convert_people_cell
})
dd
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65          Bindu
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
dd
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata
