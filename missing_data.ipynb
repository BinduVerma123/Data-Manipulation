# %%
import pandas as pd
df=pd.read_csv("/Users/apple/Downloads/py-master/pandas/handling_missing_data_fillna_dropna_interpolate/weather_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-6df1e79f6d6d> in <module>
#       1 import pandas as pd
# ----> 2 df=pd.read_csv("/Users/apple/Downloads/py-master/pandas/handling_missing_data_fillna_dropna_interpolate/weather_data.csv")
#
# ...

# %%
df=pd.read_csv("/Users/apple/Downloads/py-master/pandas/-handling_missing_data_fillna_dropna_interpolate/weather_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-d29e2970a7ba> in <module>
# ----> 1 df=pd.read_csv("/Users/apple/Downloads/py-master/pandas/-handling_missing_data_fillna_dropna_interpolate/weather_data.csv")
#
# ...

# %%
df=pd.read_csv("/Users/apple/Downloads/py-master/pandas/_handling_missing_data_fillna_dropna_interpolate/weather_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-39581fe73806> in <module>
# ----> 1 df=pd.read_csv("/Users/apple/Downloads/py-master/pandas/_handling_missing_data_fillna_dropna_interpolate/weather_data.csv")
#
# ...

# %%
df=pd.read_csv("/Users/apple/Downloads/py-master/pandas/5_handling_missing_data_fillna_dropna_interpolate/weather_data.csv",parse_dates=["day"])

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.fillna(0)

# %%
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          0.0        9.0   Sunny
# 2 2017-01-05         28.0        0.0    Snow
# 3 2017-01-06          0.0        7.0       0
# 4 2017-01-07         32.0        0.0    Rain
# 5 2017-01-08          0.0        0.0   Sunny
# 6 2017-01-09          0.0        0.0       0
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.fillna({
    'temperature':0,
    'windspeed':0,
    'event':'no event'
})

# %%
new_df
# Out:
#          day  temperature  windspeed     event
# 0 2017-01-01         32.0        6.0      Rain
# 1 2017-01-04          0.0        9.0     Sunny
# 2 2017-01-05         28.0        0.0      Snow
# 3 2017-01-06          0.0        7.0  no event
# 4 2017-01-07         32.0        0.0      Rain
# 5 2017-01-08          0.0        0.0     Sunny
# 6 2017-01-09          0.0        0.0  no event
# 7 2017-01-10         34.0        8.0    Cloudy
# 8 2017-01-11         40.0       12.0     Sunny

# %%
new_df=df.fillna(method="ffill")
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04         32.0        9.0   Sunny
# 2 2017-01-05         28.0        9.0    Snow
# 3 2017-01-06         28.0        7.0    Snow
# 4 2017-01-07         32.0        7.0    Rain
# 5 2017-01-08         32.0        7.0   Sunny
# 6 2017-01-09         32.0        7.0   Sunny
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.fillna(method="bfill")
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04         28.0        9.0   Sunny
# 2 2017-01-05         28.0        7.0    Snow
# 3 2017-01-06         32.0        7.0    Rain
# 4 2017-01-07         32.0        8.0    Rain
# 5 2017-01-08         34.0        8.0   Sunny
# 6 2017-01-09         34.0        8.0  Cloudy
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.fillna(method="ffill",axis="columns")
new_df
# Out:
#                    day          temperature            windspeed  \
# 0  2017-01-01 00:00:00                   32                    6
# 1  2017-01-04 00:00:00  2017-01-04 00:00:00                    9
# 2  2017-01-05 00:00:00                   28                   28
# 3  2017-01-06 00:00:00  2017-01-06 00:00:00                    7
# 4  2017-01-07 00:00:00                   32                   32
# 5  2017-01-08 00:00:00  2017-01-08 00:00:00  2017-01-08 00:00:00
# 6  2017-01-09 00:00:00  2017-01-09 00:00:00  2017-01-09 00:00:00
# 7  2017-01-10 00:00:00                   34                    8
# 8  2017-01-11 00:00:00                   40                   12
#
#                  event
# 0                 Rain
# 1                Sunny
# 2                 Snow
# 3                    7
# 4                 Rain
# 5                Sunny
# 6  2017-01-09 00:00:00
# 7               Cloudy
# 8                Sunny

# %%
new_df=df.fillna(method="ffill",limit=1)
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04         32.0        9.0   Sunny
# 2 2017-01-05         28.0        9.0    Snow
# 3 2017-01-06         28.0        7.0    Snow
# 4 2017-01-07         32.0        7.0    Rain
# 5 2017-01-08         32.0        NaN   Sunny
# 6 2017-01-09          NaN        NaN   Sunny
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.interpolate()
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01    32.000000       6.00    Rain
# 1 2017-01-04    30.000000       9.00   Sunny
# 2 2017-01-05    28.000000       8.00    Snow
# 3 2017-01-06    30.000000       7.00     NaN
# 4 2017-01-07    32.000000       7.25    Rain
# 5 2017-01-08    32.666667       7.50   Sunny
# 6 2017-01-09    33.333333       7.75     NaN
# 7 2017-01-10    34.000000       8.00  Cloudy
# 8 2017-01-11    40.000000      12.00   Sunny

# %%
new_df=df.interpolate(method="time")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-9c25ec099007> in <module>
# ----> 1 new_df=df.interpolate(method="time")
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    6833                                     limit_area=limit_area,
#    6834                                     inplace=inplace, downcast=downcast,
# -> 6835                                     **kwargs)
#    6836
#    6837         if inplace:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in interpolate(self, **kwargs)
#     517
#     518     def interpolate(self, **kwargs):
# --> 519         return self.apply('interpolate', **kwargs)
#     520
#     521     def shift(self, **kwargs):
#
# ...

# %%
new_df=df.interpolate(method = "time")
new_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-04373da83bf5> in <module>
# ----> 1 new_df=df.interpolate(method = "time")
#       2 new_df
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    6833                                     limit_area=limit_area,
#    6834                                     inplace=inplace, downcast=downcast,
# -> 6835                                     **kwargs)
#    6836
#    6837         if inplace:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in interpolate(self, **kwargs)
#     517
#     518     def interpolate(self, **kwargs):
# --> 519         return self.apply('interpolate', **kwargs)
#     520
#     521     def shift(self, **kwargs):
#
# ...

# %%
new_df=df.interpolate(method="day")
new_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-b906845ab462> in <module>
# ----> 1 new_df=df.interpolate(method="day")
#       2 new_df
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    6833                                     limit_area=limit_area,
#    6834                                     inplace=inplace, downcast=downcast,
# -> 6835                                     **kwargs)
#    6836
#    6837         if inplace:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in interpolate(self, **kwargs)
#     517
#     518     def interpolate(self, **kwargs):
# --> 519         return self.apply('interpolate', **kwargs)
#     520
#     521     def shift(self, **kwargs):
#
# ...

# %%
new_df=df.dropna()
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.dropna(how="all")
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.dropna(thresh=1)
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.dropna(thresh=2)
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.dropna(thresh=3)//thres is the no of valid values that should exist
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 4 2017-01-07         32.0        NaN    Rain
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
dt=pd.date_range("01-01-2017","01-11-2017")
idx=pd.DatetimeIndex(dt)
df.reindex(idx)
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
dt=pd.date_range("01-01-2017","01-11-2017")
idx=pd.DatetimeIndex(dt)
df=df.reindex(idx)
df
# Out:
#            day  temperature  windspeed event
# 2017-01-01 NaT          NaN        NaN   NaN
# 2017-01-02 NaT          NaN        NaN   NaN
# 2017-01-03 NaT          NaN        NaN   NaN
# 2017-01-04 NaT          NaN        NaN   NaN
# 2017-01-05 NaT          NaN        NaN   NaN
# 2017-01-06 NaT          NaN        NaN   NaN
# 2017-01-07 NaT          NaN        NaN   NaN
# 2017-01-08 NaT          NaN        NaN   NaN
# 2017-01-09 NaT          NaN        NaN   NaN
# 2017-01-10 NaT          NaN        NaN   NaN
# 2017-01-11 NaT          NaN        NaN   NaN
