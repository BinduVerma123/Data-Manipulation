# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
tips=sns.load_dataset('tips')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1b5f1b001b49> in <module>
#       2 import numpy as np
#       3 import seaborn as sns
# ----> 4 import matplotlib.pylot as plt
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#       6 tips=sns.load_dataset('tips')
#
# ModuleNotFoundError: No module named 'matplotlib.pylot'

# %%
sns.stripplot(x=tips['tip'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c510203af0e8> in <module>
# ----> 1 sns.stripplot(x=tips['tip'])
#
# NameError: name 'tips' is not defined

# %%
tips=sns.load_dataset('tips')

# %%
sns.stripplot(x=tips['tip'])

# %%
sns.stripplot(x=tips['total_bill'])

# %%
sns.stripplot(x='day',y='total_bill',data=tips)

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=True)

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=0.1)

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=1,linewidth=1.2)

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=1,linewidth=1.2,hue='sex')

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=1,linewidth=1.2,hue='sex',dodge=True)

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=1,linewidth=1.2,hue='smoker',dodge=True)

# %%
sns.stripplot(x='sex',y='tip',data=tips,jitter=True)

# %%
sns.stripplot(x='sex',y='tip',data=tips,jitter=True,order=['Female','Male'])

# %% [markdown]
# #to change the representation shape into Diamond

# %%
sns.stripplot(x='sex',y='tip',data=tips,jitter=True,marker='D',order=['Female','Male'])

# %%
sns.stripplot(x='day',y='total_bill',data=tips,marker='D',size=15)

# %%
sns.stripplot(x='day',y='total_bill',data=tips,marker='D',hue='sex',size=15)

# %%
sns.stripplot(x='day',y='total_bill',data=tips,marker='D',hue='sex',size=15,alpha=0.2)

# %%
sns.stripplot(x='day',y='total_bill',data=tips,marker='D',edgecolor='gray',alpha=0.3,hue='sex',size=15)

# %%
sns.stripplot(x='tip',y='day',data=tips)
sns.boxplot(x='tip',y='day',data=tips)

# %%
sns.stripplot(x='tip',y='day',data=tips,jitter=True)
sns.boxplot(x='tip',y='day',data=tips)

# %%
sns.stripplot(x='tip',y='day',data=tips,jitter=True,palette='winter_r')
sns.violinplot(x='tip',y='day',data=tips)
